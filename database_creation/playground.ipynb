# %%
# !pip install sqlmodel
# Out:
# Collecting sqlmodel
#   Downloading sqlmodel-0.0.27-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: SQLAlchemy<2.1.0,>=2.0.14 in /home/sid/system_config/researchnote/lib/python3.10/site-packages (from sqlmodel) (2.0.44)
# Requirement already satisfied: pydantic<3.0.0,>=1.10.13 in /home/sid/system_config/researchnote/lib/python3.10/site-packages (from sqlmodel) (2.12.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sid/system_config/researchnote/lib/python3.10/site-packages (from pydantic<3.0.0,>=1.10.13->sqlmodel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /home/sid/system_config/researchnote/lib/python3.10/site-packages (from pydantic<3.0.0,>=1.10.13->sqlmodel) (2.41.1)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/sid/system_config/researchnote/lib/python3.10/site-packages (from pydantic<3.0.0,>=1.10.13->sqlmodel) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/sid/system_config/researchnote/lib/python3.10/site-packages (from pydantic<3.0.0,>=1.10.13->sqlmodel) (0.4.2)
# Requirement already satisfied: greenlet>=1 in /home/sid/system_config/researchnote/lib/python3.10/site-packages (from SQLAlchemy<2.1.0,>=2.0.14->sqlmodel) (3.2.4)
# Downloading sqlmodel-0.0.27-py3-none-any.whl (29 kB)
# Installing collected packages: sqlmodel
# Successfully installed sqlmodel-0.0.27

# %%
from sqlmodel import create_engine, Session, select
from models import Patient, PatientCondition, AACTTrial
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
def get_engine():
    """Get database engine"""
    database_url = os.getenv("DATABASE_URL")
    if not database_url:
        raise RuntimeError("DATABASE_URL environment variable is not set")
    return create_engine(database_url)


engine = get_engine()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 9
#       5         raise RuntimeError("DATABASE_URL environment variable is not set")
#       6     return create_engine(database_url)
# ----> 9 engine = get_engine()
#
# Cell In[4], line 6, in get_engine()
#       4 if not database_url:
#       5     raise RuntimeError("DATABASE_URL environment variable is not set")
# ----> 6 return create_engine(database_url)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/system_config/researchnote/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/system_config/researchnote/lib/python3.10/site-packages/sqlalchemy/engine/create.py:617, in create_engine(url, **kwargs)
#     615         if k in kwargs:
#     616             dbapi_args[k] = pop_kwarg(k)
# --> 617     dbapi = dbapi_meth(**dbapi_args)
#     619 dialect_args["dbapi"] = dbapi
#     621 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#
# File ~/system_config/researchnote/lib/python3.10/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:696, in PGDialect_psycopg2.import_dbapi(cls)
#     694 @classmethod
#     695 def import_dbapi(cls):
# --> 696     import psycopg2
#     698     return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %% [markdown]
# ### Analyze Patients Table

# %%
#sample queries

with Session(engine) as session:
    statement = select(Patient).where(Patient.age >50).limit(5).offset(10)
    results = session.exec(statement)
    for patient in results:
        print(patient)
        print("*****************************")
        print(patient.conditions)
# Out:
# age=67 patient_id='38f089d5-03c9-4f27-9506-532f88459cc4' gender='female' race='White' ssn='999725517' name='Arno79 Abbott992' marital='M' ethnicity='Nonhispanic' address='58269 Christiansen Route, Boston, MA, 02133, US'
# *****************************
# [PatientCondition(id=73, patient_id='38f089d5-03c9-4f27-9506-532f88459cc4', conditions='Acute bronchitis (disorder)'), PatientCondition(id=74, patient_id='38f089d5-03c9-4f27-9506-532f88459cc4', conditions='Acute bronchitis (disorder)'), PatientCondition(id=75, patient_id='38f089d5-03c9-4f27-9506-532f88459cc4', conditions='Acute bronchitis (disorder)'), PatientCondition(id=76, patient_id='38f089d5-03c9-4f27-9506-532f88459cc4', conditions='Acute bronchitis (disorder)'), PatientCondition(id=77, patient_id='38f089d5-03c9-4f27-9506-532f88459cc4', conditions='Acute bronchitis (disorder)'), PatientCondition(id=78, patient_id='38f089d5-03c9-4f27-9506-532f88459cc4', conditions='Chronic sinusitis (disorder)'), PatientCondition(id=79, patient_id='38f089d5-03c9-4f27-9506-532f88459cc4', conditions='Prediabetes'), PatientCondition(id=80, patient_id='38f089d5-03c9-4f27-9506-532f88459cc4', conditions='Chronic obstructive bronchitis (disorder)'), PatientCondition(id=81, patient_id='38f089d5-03c9-4f27-9506-532f88459cc4', conditions='Acute bronchitis (disorder)')]
# age=55 patient_id='74d6c5ec-7fce-4925-a565-271b1620b6f7' gender='male' race='White' ssn='999496524' name='Athena927 Abbott992' marital='M' ethnicity='Nonhispanic' address='1747 Logan Forges, Apt. 470, Springfield, MA, 01139, US'
# *****************************
# [PatientCondition(id=89, patient_id='74d6c5ec-7fce-4925-a565-271b1620b6f7', conditions='Prediabetes'), PatientCondition(id=90, patient_id='74d6c5ec-7fce-4925-a565-271b1620b6f7', conditions='Viral sinusitis (disorder)'), PatientCondition(id=91, patient_id='74d6c5ec-7fce-4925-a565-271b1620b6f7', conditions='Laceration of foot'), PatientCondition(id=92, patient_id='74d6c5ec-7fce-4925-a565-271b1620b6f7', conditions='Viral sinusitis (disorder)'), PatientCondition(id=93, patient_id='74d6c5ec-7fce-4925-a565-271b1620b6f7', conditions='Fracture subluxation of wrist')]
# age=81 patient_id='c4f08015-7123-4279-a664-6bdf939a88dd' gender='female' race='White' ssn='999721258' name='Aubree187 Abbott992' marital='M' ethnicity='Nonhispanic' address='37130 Cartwright Orchard, Suite 277, Tyngsborough, MA, 01879, US'
# *****************************
# [PatientCondition(id=94, patient_id='c4f08015-7123-4279-a664-6bdf939a88dd', conditions='Hypertension'), PatientCondition(id=95, patient_id='c4f08015-7123-4279-a664-6bdf939a88dd', conditions='Prediabetes'), PatientCondition(id=96, patient_id='c4f08015-7123-4279-a664-6bdf939a88dd', conditions='Diabetes'), PatientCondition(id=97, patient_id='c4f08015-7123-4279-a664-6bdf939a88dd', conditions='Diabetic retinopathy associated with type II diabetes mellitus (disorder)'), PatientCondition(id=98, patient_id='c4f08015-7123-4279-a664-6bdf939a88dd', conditions='Nonproliferative diabetic retinopathy due to type 2 diabetes mellitus (disorder)'), PatientCondition(id=99, patient_id='c4f08015-7123-4279-a664-6bdf939a88dd', conditions='Stroke'), PatientCondition(id=100, patient_id='c4f08015-7123-4279-a664-6bdf939a88dd', conditions='Osteoarthritis of knee')]
# age=71 patient_id='baa3076a-19cd-4012-97f0-af5a12c77d07' gender='male' race='White' ssn='999921674' name='Aubrey786 Abbott992' marital='M' ethnicity='Nonhispanic' address='47144 Lou Square, Dracut, MA, 01826, US'
# *****************************
# [PatientCondition(id=101, patient_id='baa3076a-19cd-4012-97f0-af5a12c77d07', conditions='Chronic sinusitis (disorder)'), PatientCondition(id=102, patient_id='baa3076a-19cd-4012-97f0-af5a12c77d07', conditions='Appendicitis'), PatientCondition(id=103, patient_id='baa3076a-19cd-4012-97f0-af5a12c77d07', conditions='History of appendectomy'), PatientCondition(id=104, patient_id='baa3076a-19cd-4012-97f0-af5a12c77d07', conditions='Sinusitis (disorder)'), PatientCondition(id=105, patient_id='baa3076a-19cd-4012-97f0-af5a12c77d07', conditions='Sprain of ankle'), PatientCondition(id=106, patient_id='baa3076a-19cd-4012-97f0-af5a12c77d07', conditions='Acute viral pharyngitis (disorder)'), PatientCondition(id=107, patient_id='baa3076a-19cd-4012-97f0-af5a12c77d07', conditions='Acute bronchitis (disorder)'), PatientCondition(id=108, patient_id='baa3076a-19cd-4012-97f0-af5a12c77d07', conditions='Viral sinusitis (disorder)')]
# age=76 patient_id='6d73b8fc-b72a-44e0-8d9b-b57571d7db92' gender='female' race='White' ssn='999395004' name='Audreanne163 Abbott992' marital='M' ethnicity='Nonhispanic' address='88848 Fanny Harbors, Suite 701, Newton, MA, 02462, US'
# *****************************
# [PatientCondition(id=109, patient_id='6d73b8fc-b72a-44e0-8d9b-b57571d7db92', conditions='Acute bronchitis (disorder)'), PatientCondition(id=110, patient_id='6d73b8fc-b72a-44e0-8d9b-b57571d7db92', conditions='Acute bronchitis (disorder)'), PatientCondition(id=111, patient_id='6d73b8fc-b72a-44e0-8d9b-b57571d7db92', conditions='Acute bronchitis (disorder)'), PatientCondition(id=112, patient_id='6d73b8fc-b72a-44e0-8d9b-b57571d7db92', conditions='Acute bronchitis (disorder)'), PatientCondition(id=113, patient_id='6d73b8fc-b72a-44e0-8d9b-b57571d7db92', conditions="Alzheimer's disease (disorder)"), PatientCondition(id=114, patient_id='6d73b8fc-b72a-44e0-8d9b-b57571d7db92', conditions='Acute bronchitis (disorder)')]

# %%
import json
filepath = r'D:\clinical-trials-mcp\data\raw\clinical_documents_with_metadata_final.json'
with open(filepath,'r',encoding='utf-8') as f:
        data = json.load(f)

for nct_id, content in data.items():

    text = content['document']
    metadata = content['metadata']
    conds_count = metadata.get('conditions_count',0)
    conditions=[]
    for i in range(conds_count):
        condition = metadata.get(f'condition_{i+1}','')
        conditions.append(condition)
# Out:
# NCT00881959
# Title: Study of Root Coverage With Acellular Dermal Matrix: Puros Dermis Versus Alloderm
# Eligibility: Inclusion Criteria: * Male or female, of any ethnicity, between 18 and 99 years of age. * No known allergies to study material. * Able to communicate with the investigator and read, understand, and sign the informed consent form. * Maxillary incisor, canine, or premolar with at least one Miller's Class I or II gingival recession defects that are not adjacent to one another. * Depth of the gingival recession defects of 2mm or greater. * No gingival surgery within the past 12 months at the defect site. No prior antibiotic use within 3 months with less than 2 weeks durations. * Ability to maintain good oral hygiene. Exclusion Criteria: * Patients taking any medications known to cause gingival enlargement. * Patients with unstable systemic diseases. * Patients with compromised immune systems or unstable bleeding disorders. * Patients with active infectious diseases (e.g. hepatitis, tuberculosis, HIV, etc.). * Patients with a mental disability that may hinder participation in the study (e.g. inability to follow through with oral hygiene instructions, postoperative instructions, follow-up commitments, etc.). * Patients taking steroid medications. * Tobacco use or smoking within 1 year of screening visit (e.g. cigarettes, pipes, cigars, chew). * Pregnant females or females attempting to get pregnant. * Other conditions the investigator feels would inhibit from a good candidate for the study.
# Conditions: gingival recession
# Locations: [{"facility": "University of Alabama", "city": "Birmingham", "state": "Alabama", "zip": "35294", "country": "United States", "geoPoint": {"lat": 33.52066, "lon": -86.80249}}, {"facility": "University of Michigan", "city": "Ann Arbor", "state": "Michigan", "zip": "48109-1078", "country": "United States", "geoPoint": {"lat": 42.27756, "lon": -83.74088}}, {"facility": "University of Medicine and Dentistry of New Jersey", "city": "Newark", "state": "New Jersey", "zip": "07103-0009", "country": "United States", "geoPoint": {"lat": 40.73566, "lon": -74.17237}}, {"facility": "University of Rochester", "city": "Rochester", "state": "New York", "zip": "14620", "country": "United States", "geoPoint": {"lat": 43.15478, "lon": -77.61556}}]
# Interventions:
#   - Type: DEVICE ; Name: Puros Dermis versus Alloderm ; Description: Puros Dermis and Alloderm (both Allograft Tissue Matrix)
# Outcomes:
#   - PRIMARY: Non -Inferiority of Dermis to Alloderm ; Description: Non -inferiority of Dermis to Alloderm will be assessed by comparison of the average change (from the preoperative value) in gingival recession measured at 12 months between defects receiving Puros Dermis and those receiving Alloderm. ; Timeframe: 12 months
# ['gingival recession']
